# %% [markdown]
# # 🌟 **<span style="color:blue">Day 1: Introduction to Python Programming</span>**

# %% [markdown]
# # 1.  **<span style="color:blue">Programming</span>**

# %% [markdown]
# ## 🎯 **1.1. What is Programming?**

# %% [markdown]
#  **Programming** is **telling a computer what to do** using a language it understands.
#
# - 🤖 Think of a **computer** as a super-fast, obedient, but **literal** robot.
# - 💻 You write **instructions** (code) → Computer **executes** them → Magic happens!
#       Programming = Writing step-by-step recipes for computers!

# %% [markdown]
# ## 🎯 **1.2. Types of Programming languages?**

# %%
from IPython.display import YouTubeVideo, Image

# %%
cd D:\Training
# Out:
# d:\Training

# %% [markdown]
# ### **A. High-Level Languages**

# %% [markdown]
# - Easy for humans to read and write.
# - Uses words and symbols closer to English.
# - Examples: Python, Java

# %%
# Image("High.png",width=300, height=300 )

# %% [markdown]
# ### **B. Low-Level Languages**

# %% [markdown]
# Closer to machine hardware than human language.
#
# - Harder to read
# - Very fast execution
# - Gives more control over memory
# - Hardware-specific
# - Assembly Language

# %%
Image("Low.png",width=500, height=500)

# %% [markdown]
# ### **C. Machine Languages**

# %% [markdown]
# - The lowest-level language → understood directly by the computer.
# - Only 0s and 1s
# - Extremely fast
# - Very hard for humans
# - Specific to each CPU architecture

# %%
Image("Machine.png",width=300, height=300 )

# %% [markdown]
# ## 🎯 **1.3. What is Python Programming?**

# %% [markdown]
# **Python** is a high-level programming language used to write computer programs.
# - Created by **Guido van Rossum** and first released in 1991.
# - Designed to be easy to read, easy to write, and beginner-friendly.
# - Uses simple, English-like syntax.
# - Works on all major **operating systems** (Windows, macOS, Linux).
# - Supports multiple programming styles (procedural, object-oriented, functional).
# - Comes with a huge standard library for almost any task.
# - Used for **web development**, **data science**, **AI/ML**, **automation**, **games**, **scripting**, and more.
# - Has a large and supportive global community.
# - Free and open-source.

# %% [markdown]
# ## 🎯 **1.4. Why is Python Programming?**

# %% [markdown]
# ### <span style="color:blue"> Key Reasons</span>

# %% [markdown]
# - **Easy to learn** → simple English-like syntax
# - **Beginner-friendly** → great for students from any field
# - **Very powerful** → used in <span style='color:red'>AI</span>, <span style='color:green'>Machine Learning</span>, <span style='color:brown'>Data Science</span>, <span style='color:blue'>Web Apps</span>, <span style='color:cyan'>Automation</span>
# - **Huge community support** → millions of developers worldwide
# - **Large library ecosystem** → NumPy, Pandas, TensorFlow, Django, etc.
# - **Cross-platform** → runs on **Windows**, macOS, Linux
# - **Faster development** → write fewer lines of code
# - **Highly flexible** → supports multiple styles (OOP, procedural, functional)
# - **Great for research** → widely used in scientific computing
# - **Free and open-source** → no cost to use or distribute

# %%
import folium
m = folium.Map(location=[9.0192, 38.7525], zoom_start=6)
folium.Marker([9.0192, 38.7525], popup='አዲስ አበባ').add_to(m)
folium.Marker([11.5742, 37.3614], popup='ባህር ዳር').add_to(m)
m

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = """
Ethiopia, officially the Federal Democratic Republic of Ethiopia, is a landlocked country
located in the Horn of Africa region of East Africa. It shares borders with Eritrea to the
north, Djibouti to the northeast, Somalia to the east, Kenya to the south, South Sudan to
the west, and Sudan to the northwest.

Ethiopia covers a land area of 1,104,300 square kilometres (426,400 sq mi). As of 2025, it
has around 135 million inhabitants, making it the 14th-most populous country. The national
capital and largest city, Addis Ababa, lies several kilometres west of the East African Rift
that splits the country into the African and Somali tectonic plates.

The Aksumite Empire extended its realm over Eritrea and the northern region of Ethiopia,
maintaining a unified civilization for nearly 900 years. Christianity was embraced by the
kingdom in the 4th century, while Islam arrived during the first Hijra.

After the collapse of Aksum in 960, the Zagwe dynasty ruled north-central Ethiopia until
being overthrown by Yekuno Amlak in 1270, inaugurating the Ethiopian Empire and the
Solomonic dynasty, which claimed descent from the biblical Solomon and Queen of Sheba
through their son Menelik I.

By the 14th century, the empire expanded territorially and militarily, most notably during
the Ethiopian–Adal War. This period ultimately led to fragmentation and the era of
Zemene Mesafint in the mid-18th century.

Emperor Tewodros II ended Zemene Mesafint in 1855, marking the reunification and
modernization of Ethiopia.
"""

# የቃላት ደመና መፍጠር
wordcloud = WordCloud(width=800, height=400, background_color='cyan').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import plotly.express as px
df = px.data.gapminder()
# One powerful line to create an interactive 4D world map
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", 
                 size="pop", color="continent", hover_name="country",
                 log_x=True, size_max=60, range_y=[25,90])
fig.show()

# %%
import seaborn as sns
# Automatically creates a grid of histograms and scatter plots for every variable
sns.pairplot(sns.load_dataset("iris"), hue="species", palette="viridis")

# %%
# Python Draws Art by Itself
import turtle
for i in range(100):
    turtle.forward(i*2)
    turtle.right(91)

# %%
# #  Simulating Rainfall
import random, time
for _ in range(100):
    print(" " * random.randint(0,50) + "💧")
    time.sleep(0.05)

# %%
# # Predict ages
birth = int(input("Enter birth year: "))
print("You are about", 2025-birth, "years old")

# %%
#!pip install gtts

# %%
# Create chatboot
print("🤖 Bot: Hello! I am your Python assistant.")
print("🤖 Bot: What is your name?")

user_name = input("You: ")

print(f"🤖 Bot: Nice to meet you, {user_name}!")
print("🤖 Bot: I am curious—what do you enjoy doing in your free time?")

hobby = input(f"{user_name}: ")

print(f"🤖 Bot: That sounds interesting!")
print(f"🤖 Bot: {hobby.capitalize()} is a great activity, {user_name}.")
print("🤖 Bot: Python can help you learn, analyze, or even build projects related to that!")
# Out:
# ሮቦት፡ ዋው! reading books መውደድህ በጣም ግሩም ነው!

# %%
# Interactive Smart Irrigation Advisor
# Beginner-friendly but professional-level logic

import time

print("🌱 Smart Irrigation Advisor v2.0")
print("🤖 Welcome! I will help you decide when and how to irrigate your crops.\n")

# User inputs
crop = input("🌾 Enter crop type (e.g., maize, wheat, teff): ").strip().lower()
soil_type = input("🪨 Enter soil type (sand / loam / clay): ").strip().lower()
moisture_level = int(input("💧 Enter current soil moisture level (0–100%): "))
temperature = float(input("🌡️ Enter today's temperature (°C): "))

time.sleep(1)

print("\n📡 Analyzing field conditions...")
time.sleep(1)

# Soil water holding capacity
soil_factor = {
    "sand": 1.5,
    "loam": 1.0,
    "clay": 0.7
}

# Crop water sensitivity
crop_factor = {
    "maize": 1.3,
    "wheat": 1.1,
    "teff": 1.0
}

sf = soil_factor.get(soil_type, 1.0)
cf = crop_factor.get(crop, 1.0)

# Decision logic
stress_index = (100 - moisture_level) * sf * cf

if stress_index > 80 or moisture_level < 30:
    decision = "IRRIGATION REQUIRED"
    water_liters = round(stress_index * (1 + temperature / 40), 1)

elif 40 <= stress_index <= 80:
    decision = "MONITOR CLOSELY"
    water_liters = 0

else:
    decision = "NO IRRIGATION NEEDED"
    water_liters = 0

# Intelligent output
print("\n🧠 SYSTEM DECISION")
print("────────────────────")
print(f"🌾 Crop: {crop.capitalize()}")
print(f"🪨 Soil Type: {soil_type.capitalize()}")
print(f"💧 Moisture Level: {moisture_level}%")
print(f"🌡️ Temperature: {temperature} °C")
print(f"📊 Stress Index: {round(stress_index,1)}")

print(f"\n⚙️ Recommendation: {decision}")

if water_liters > 0:
    print(f"💦 Suggested Irrigation Volume: {water_liters} liters")
    print("🚿 Action: Activate irrigation system")
else:
    print("✅ Action: No irrigation required at this time")

print("\n📁 Decision stored for farm management records.")
print("🤖 Advisor session completed.")

# %%
# %pip install ydata-profiling
# %pip install sweetviz
# %pip install dtale

# %%
import seaborn as sns
from ydata_profiling import ProfileReport

df = sns.load_dataset("penguins")
ProfileReport(df, title="Automatic Data Science").to_file("penguins.html")

# %%
import sweetviz as sv
import seaborn as sns
df = sns.load_dataset("penguins")
sv.analyze(df).show_html()

# %%
import dtale
dtale.show(df)

# %%
#  #!pip install ydata-profiling
from ydata_profiling import ProfileReport

# ሙሉ የስታቲስቲክስ ሪፖርት ማመንጨት
profile = ProfileReport(df, title="የምርምር ዳታ ትንተና ሪፖርት")
profile.to_notebook_iframe()

# %% [markdown]
# ## 🎯 **1.5. Trends of Python Programming over time**

# %%
YouTubeVideo('-EyWfyT3OW4', width=800, height=450)

# %% [markdown]
# # 2.  **<span style="color:blue">Python Setup</span>**

# %% [markdown]
# ## 🎯 **1.1. Python Setup Options**

# %%
## Check if Python is already installed 
python --version

# %% [markdown]
# ### **1️⃣ Install <span style="color:blue">Python</span>(Official Website)**

# %% [markdown]
# 🔗 **Download**: https://www.python.org/downloads/
# - Simple and direct installation
# - Works on Windows, macOS, Linux
# - Includes IDLE editor
# - Best for beginners

# %% [markdown]
# **Verify installation**

# %%
python --version
pip --version

# %% [markdown]
# ### 2️⃣**Install Python Using <span style="color:blue">Anaconda</span>**

# %% [markdown]
# 🔗 **Download**: https://www.anaconda.com/products/distribution
# - Includes Python + R + 8000+ scientific packages
# - Comes with Jupyter Notebook & Spyder
# - Best for research, data science, climate & soil analysis

# %% [markdown]
# ### 3️⃣ **<span style="color:blue">Online </span>Python Platforms (No Installation Needed)**

# %% [markdown]
# -  ✅ **Google Colab**
#     - [https://colab.research.google.com](https://colab.research.google.com)
#     - Runs in browser
#     - Free GPU/TPU for ML
#     - Best for data science notebooks
# - ✅ **Kaggle Notebooks**
#     - [https://www.kaggle.com/code](https://www.kaggle.com/code)
#     - Powerful cloud notebooks
#     - Free datasets + GPUs
#     - Great for ML research
# - ✅ **Jupyter Notebook Online (Binder)**
#     - [https://mybinder.org](https://mybinder.org)
#     - Launches notebooks in the cloud
#     - No login needed
#     - Temporary environment
# - ✅ **Trinket**
#     - [https://trinket.io/python3](https://trinket.io/python3)
#     - Simple beginner platform
#     - Runs directly in browser
#     - Great for teaching basics
# - ✅ **PythonAnywhere**
#     - [https://www.pythonanywhere.com](https://www.pythonanywhere.com)
#     - Cloud-based Python environment
#     - Good for web apps
#     - Runs 24/7
# - ✅ **Deepnote**
#     - [https://deepnote.com](https://deepnote.com)
#     - Collaborative notebooks
#     - Real-time teamwork
#     - Best for classroom use
# - ✅ **Glitch**
#     - [https://glitch.com](https://glitch.com)
#     - Build & host Python web apps
#     - Easy deployment
#     - Good for projects
# - ✅ **Replit**
#     - [https://replit.com](https://replit.com)
#     - Online code editor
#     - Run Python instantly
#     - Good for assignments & projects

# %% [markdown]
# ### 4️⃣ Use an <span style="color:blue">IDE (Integrated Development Environment)</span>

# %% [markdown]
# #### **Top IDEs for Python**

# %% [markdown]
# - 🟦 **<span style="color:green">VS Code</span>**
#   - 🔗 https://code.visualstudio.com
#   - Fast, powerful, flexible
# - 🟩 **<span style="color:green">PyCharm</span>**
#   - 🔗 https://www.jetbrains.com/pycharm
#   - Professional, smart, great for big projects
# - 🟨 **<span style="color:green">Spyder</span>**
#   - 🔗 https://www.spyder-ide.org
#   - Data-science focused, MATLAB-like
# - 🟧 **<span style="color:green">Thonny</span>**
#   - 🔗 https://thonny.org
#   - Simple, clean, best for beginners

# %% [markdown]
# ### **Create a virtual environment**

# %% [markdown]
# - A virtual environment is an isolated workspace for a Python project.
# - It allows you to manage project-specific dependencies without affecting other projects or the system Python installation.

# %% [markdown]
# **Step 1**: Navigate to your project folder

# %% [markdown]
# **Step 2**: Create the virtual environment

# %% [markdown]
# **python -m venv venv**
#  - venv is the environment name (commonly used)
#  - This creates a folder containing an isolated Python interpreter

# %% [markdown]
# **Step 3**: Activate the virtual environment

# %%
venv\Scripts\activate

# %% [markdown]
# **Step 4**: Upgrade pip

# %%
python -m pip install --upgrade pip

# %% [markdown]
# **Step 5**: Install required packages

# %%
pip install numpy

# %% [markdown]
# # 3.  **<span style="color:blue">Python Basic Syntax</span>**

# %% [markdown]
# ## 🎯 **3.1. Python Syntax**

# %% [markdown]
# ### A. 📝 <span style='color:blue'>Comments </span>

# %% [markdown]
# - Comments are notes written in the code for humans, not for the computer.
# - Python ignores comments when running the program.
# - Used to explain code, make it readable, or disable lines temporarily.

# %% [markdown]
# #### 1. Single-Line Comment
# - Begins with #.
# - Python ignores everything after # on that line.

# %%
# The value 10 is stored in X variable
x = 10  
x

# %% [markdown]
# #### 2. Multi-Line Comment
# - Python has no official multi-line comment syntax.
# - We use triple quotes """ ... """ or ''' ... ''' to write comments across many lines.
# - These are actually unused multiline strings but function as comments.

# %%
"""
This is a multi-line comment.
You can write many lines here.
Useful for long explanations.
"""

# %% [markdown]
# #### 3 3. Inline Comment
# - A comment written at the end of a line of code using #.

# %%
speed = 80  # speed in km/h

# %% [markdown]
# ### B 🖨️  <span style='color:blue'>Print() Function </span>

# %% [markdown]
# - print() is a built-in Python function used to display/output information on the screen.
# - It is one of the most important and most used functions.
# - It can display text, numbers, variables, results of calculations, and more.

# %% [markdown]
# **Syntax**
#     - print(value)

# %%
# Examples
print("Hello, World!")

# %%
print(10)
print(3.14)
print("These are numbers")

# %%
# You can combine text and numbers in one output by separating them with a comma
print("My age is", 35)

# %%
print("A", "B", "C",  sep="-")

# %%
# Print Without a New Line
print("Hello World!", end=" ")
print("I will print on the same line.")

# %%
# You can use either " double quotes or ' single quotes
print("This will work!")
print('This will also work!')

# %%
# Print with Formatting (f-strings)
name = "Tadele"
print(f"My name is ",{name})

# %% [markdown]
# ### C. 📝 <span style='color:blue'>Input () Function </span>

# %% [markdown]
# In Python, the **input()** function allows the program to take input from the user as a string.

# %% [markdown]
# **Syntax**
#  - Variable = input("Prompt message for the user: ")

# %%
#Example
name = input("Enter your name: ")
print("Hello, " + name + "! Welcome to Python.")

# %%
print("Welcome to the Secret Code Game!")
secret_code = "python123"
guess = input("Guess the secret code: ")

if guess == secret_code:
    print("Congratulations! You guessed it!")
else:
    print("Oops! Try again next time.")

# %% [markdown]
# ### D 📏  <span style='color:blue'>Python Indentetion </span>

# %% [markdown]
# **What is Indentation?**
# - Indentation means adding spaces (or a tab) at the beginning of a line.
# - In Python, indentation is NOT optional. It is part of the syntax.
# - It tells Python which lines of code belong together.
# - Instead, **Python** uses indentation to define blocks of code, such as:
#      - **loops**
#      - **<span style="color:green">if </span>statements**
#      - **functions**
#      - **classes**
# - If indentation is incorrect → Python will show an error.
# ✔ **Default Rule**
# - Use 4 spaces for indentation.
# - Never mix spaces and tabs.

# %%
# Example 1: Indentation in an If Statement
# Correct:
if age > 18:
    print("Adult")

# %%
# Example 2: Indentation in a Loop
for i in range(5):
    print(i)

# %%
# Example 3: Indentation in a Function
def greet(name):
    print("Hello,", name)

# %%
# Incorrect (no indentation):
if age > 18:
print("Adult")   # ❌ 🧩Error

# %% [markdown]
# # 4.  **<span style="color:blue">Variables & Data types</span>**

# %% [markdown]
# ##  **<span style="color:blue">Variabls</span>**

# %% [markdown]
# <span style="color:#00A8E8; font-size:15px;"> A **variable** is a storage name </span>that holds a value you can use later in your code.

# %% [markdown]
# - <b><span style="color:#FF1493;">Variables help you store data.</span></b>
# - <b><span style="color:#33FF57;">You can update them anytime.</span></b>
# - <b><span style="color:#00BFFF;">They make programs dynamic and powerful!</span></b>

# %% [markdown]
# ### **Creating Variables**

# %%
name = "Tadele"
age = 25
temperature = 23.7
is_student = True

# %% [markdown]
# ### **Displaying Variabls**

# %%
# print(name)
# print(age)
# print(temperature)
# print(is_student)

# %% [markdown]
# ### **Variable Rules**

# %% [markdown]
# <b><span style="color:#e67e22; font-size:18px;"> Rules for Naming Variables</span></b>
#
# ✔ Must start with a letter or underscore
# ✔ Cannot start with a number
# ✔ Cannot contain spaces
# ✔ Case-sensitive (age ≠ Age)
# ✔ Use readable names (rainfall_mm, student_age)

# %% [markdown]
# ##  **<span style="color:blue">Data Types</span>**

# %% [markdown]
# ### Built-in Data Types
# - In programming, data type is an important concept.
# - Variables can store data of different types, and different types can do different things.
# - Each type defines how data is stored and how it behaves in a program.
# - Python has the following data types built-in by default, in these categories:

# %% [markdown]
# | **Category**      | **Type(s)**                  | **Description**                         | **Example**                     |
# |------------------|-----------------------------|-----------------------------------------|---------------------------------|
# | 🔤 Text           | `str`                       | Text / characters / words               | `"Hello, Python"`               |
# | 🔢 Numeric        | `int`                       | Whole numbers                           | `10`                            |
# |                  | `float`                     | Decimal / floating numbers              | `3.14`                          |
# |                  | `complex`                   | Real + imaginary numbers                | `2 + 3j`                        |
# | 📚 Sequence       | `list`                      | Ordered, changeable collection          | `[1, 2, 3]`                     |
# |                  | `tuple`                     | Ordered, unchangeable collection        | `(1, 2, 3)`                     |
# |                  | `range`                     | Sequence of numbers                     | `range(5)`                       |
# | 🗂️ Mapping        | `dict`                      | Key–value pairs                          | `{"name": "Tsegaye", "age": 25}`|
# | 🎯 Set            | `set`                       | Unique unordered values                 | `{1, 2, 3}`                     |
# |                  | `frozenset`                 | Immutable set                            | `frozenset({1, 2, 3})`          |
# | 🔘 Boolean        | `bool`                      | `True` or `False`                        | `True`                          |
# | 📦 Binary         | `bytes`                     | Immutable binary data                    | `b"Hello"`                       |
# |                  | `bytearray`                 | Mutable binary data                      | `bytearray([65,66,67])`         |
# |                  | `memoryview`                | Access to memory buffers                 | `memoryview(b"ABC")`            |
# | 🚫 None           | `NoneType`                  | Represents no value / empty             | `None`                          |

# %%
## To verify the type of any object in Python, use the type() function:
type()

# %%
#Examples
x = 1    
y = 2.8  
z = 1j

# %%
print(type(x))
print(type(y))
print(type(z))

# %% [markdown]
# ### **Python Numbers**

# %% [markdown]
# - There are three numeric types in Python:
#    - int
#    - float
#    - complex

# %% [markdown]
# **Int, or integer**, is a whole number, positive or negative, without decimals, of unlimited length.

# %%
x = 1
y = 35656222554887711
z = -3255522

# %%
print(type(x))
print(type(y))
print(type(z))

# %% [markdown]
# **Float, or "floating point number"** is a number, positive or negative, containing one or more decimals.

# %%
x = 1.10
y = 1.0
z = -35.59

# %%
print(type(x))
print(type(y))
print(type(z))

# %% [markdown]
# **Complex numbers** are written with a "j" as the imaginary part:

# %%
x = 3+5j
y = 5j
z = -5j

# %%
print(type(x))
print(type(y))
print(type(z))

# %%
### **Random Number**

# %%
import random

# print(random.randrange(2, 10))
# print(random.randint(2,20))

# %% [markdown]
# **Python Casting**
#   - is the process of converting a value from one data type to another.

# %%
x = 10        # int
y = 3.14      # float

result = x + y
print(result)     # 13.14 → int promoted to float
print(type(result))  # <class 'float'>

# %% [markdown]
# **Examples**

# %%
# Integers
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3

# %%
# Floats
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2

# %%
# Strings
x = str("s1") # x will be 's1'
y = str(2)    # y will be '2'
z = str(3.0)  # z will be '3.0'

# %% [markdown]
# ### **Python Strings (str)**

# %% [markdown]
# -  **A string** in Python is a sequence of characters used to store text.
# -  **Strings** in python are surrounded by either single quotation marks, or double quotation marks.
# -  **String Characteristics**
#     - Text data
#     - Ordered (characters have positions)
#     - Immutable (cannot be changed once created)
#     - Indexable & sliceable
#     - Iterable

# %% [markdown]
# **Create Strings**

# %%
name = "Python"
city = 'Bahir dar'
sentence = """This is a multi-line string."""

# %% [markdown]
# **Accessing Characters**

# %%
word = "Python"
print(word[0])   # P
print(word[1])   # y
print(word[-1])  # n

# %% [markdown]
# **Sclicing Strings**

# %%
text = "Hello Python"
print(text[0:5])    # Hello
print(text[6:])     # Python
print(text[:5])     # Hello

# %% [markdown]
# **Assign String to a Variable**

# %%
a = """Assigning a string to a variable 
is done with the variable name followed 
by an equal sign and the string:."""
print(a)

# %% [markdown]
# **Usefull string Methods**

# %%
text = "python programming"

text.upper()      # 'PYTHON PROGRAMMING'
text.lower()      # 'python programming'
text.title()      # 'Python Programming'
text.strip()      # remove spaces
text.replace("python", "AI")

# %% [markdown]
# **String <span style="color:green">Concatenation</span>**

# %%
a = "Hello"
b = "World"
print(a + " " + b)   # Hello World

# %% [markdown]
# **String Formatting**

# %%
# f-string (most modern)
name = "Tadele"
age = 25
print(f"My name is {name} and I am {age} years old.")

# %%
# .format()
print("Hello {}!".format("Python"))

# %%
# Example
paragraph = (
    "Hello, my name is {name}. Today, {name} will show you how Python formatting works. "
    "Many beginners find it helpful when {name} is used repeatedly in examples. "
    "In this short demo, you will see {name} appear multiple times. "
    "By the end, {name} hopes you understand `.format()` clearly!"
)

print(paragraph.format(name="Tadele"))

# %% [markdown]
# **Escape Characters**

# %%
print("He said \"Hello\"")
print("Line1\nLine2")
print("Tab\tSpace")

# %% [markdown]
# ### **Python Booleans (bool)**

# %% [markdown]
# - A Boolean in Python represents one of two values:
#   - True
#   - False
# - Booleans are used to make decisions, control conditions, and evaluate expressions.

# %% [markdown]
# **Boolean Values**
# - In Python, the Boolean type is bool:

# %%
x = True
y = False
print(type(x))   # <class 'bool'>

# %% [markdown]
# **Boolean from Expressions (Comparisons)**
# - Booleans are often created by comparison operators:

# %%
print(10 > 5)    # True
print(10 == 5)   # False
print(7 <= 7)    # True

# %% [markdown]
# **Boolean in Conditions (if statements)**

# %%
age = 20
if age >= 18:
    print("Adult")
else:
    print("Not adult")

# %% [markdown]
# **Boolean Functions**
#    - The built-in bool() converts values into True or False:
#    - Values considered <span style="color:red">False:</span>
#         - 0
#         - "" (empty string)
#         - [] (empty list)
#         - () (empty tuple)
#         - {} (empty dict)
#         - None
#         - False
# - Everything else is <span style="color:green">True</span>.

# %% [markdown]
# **Logical Operators**

# %%
# AND
print(True and False)   # False
# OR
print(True or False)    # True
# NOT
print(not True)         # False

# %% [markdown]
# # 5.  **<span style="color:blue">Python Opreators</span>**

# %% [markdown]
# - **Operators** are symbols used to perform actions on variables and values.

# %%
Image("operators.png",width=300, height=300)

# %%
Image("operator.png",width=500, height=500

# %% [markdown]
# ## **Assignment Opreators**

# %% [markdown]
# - Used to assign values.

# %% [markdown]
# | Operator | Meaning             | Example   | Same as      |
# | -------- | ------------------- | --------- | ------------ |
# | `=`      | Assign              | `x = 5`   | —            |
# | `+=`     | Add & assign        | `x += 3`  | `x = x + 3`  |
# | `-=`     | Subtract & assign   | `x -= 3`  | `x = x - 3`  |
# | `*=`     | Multiply & assign   | `x *= 3`  | `x = x * 3`  |
# | `/=`     | Divide & assign     | `x /= 3`  | `x = x / 3`  |
# | `//=`    | Floor divide assign | `x //= 2` | `x = x // 2` |
# | `**=`    | Power assign        | `x **= 2` | `x = x ** 2` |

# %%
# Examples
x = 5
x += 10
x *= 2
print(x)
# Out:
# 30

# %% [markdown]
# ## **Arithmetic Operators**

# %% [markdown]
# - Used for mathematical operations.

# %% [markdown]
# | Operator | Meaning        | Example  | Result |
# | -------- | -------------- | -------- | ------ |
# | `+`      | Addition       | `5 + 2`  | 7      |
# | `-`      | Subtraction    | `5 - 2`  | 3      |
# | `*`      | Multiplication | `5 * 2`  | 10     |
# | `/`      | Division       | `5 / 2`  | 2.5    |
# | `%`      | Modulus        | `5 % 2`  | 1      |
# | `**`     | Exponent       | `2 ** 3` | 8      |
# | `//`     | Floor Division | `5 // 2` | 2      |

# %%
#Examples
x = 10
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
print(x // y)

# %% [markdown]
# ## **Comparison Operators**

# %% [markdown]
# - Used to compare values (result is True/False).

# %% [markdown]
# | Operator | Meaning          | Example         |
# | -------- | ---------------- | --------------- |
# | `==`     | Equal            | `5 == 5` → True |
# | `!=`     | Not equal        | `5 != 3` → True |
# | `>`      | Greater than     | `5 > 3` → True  |
# | `<`      | Less than        | `5 < 3` → False |
# | `>=`     | Greater or equal | `6 >= 6` → True |
# | `<=`     | Less or equal    | `3 <= 5` → True |

# %%
# Examples
x = 5
y = 3

# %%
print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)

# %% [markdown]
# ## **Logical Operators**

# %% [markdown]
# - Used to combine conditions.

# %% [markdown]
# | Operator | Meaning   | Example          | Result |
# | -------- | --------- | ---------------- | ------ |
# | `and`    | Both True | `True and False` | False  |
# | `or`     | One True  | `True or False`  | True   |
# | `not`    | Reverse   | `not True`       | False  |

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)

# %% [markdown]
# ## **Membership Operators**

# %% [markdown]
# - Used to test if a value is in a sequence.

# %% [markdown]
# | Operator | Meaning        | Example                   |
# | -------- | -------------- | ------------------------- |
# | `in`     | Exists in      | `"a" in "cat"` → True     |
# | `not in` | Does not exist | `5 not in [1,2,3]` → True |

# %%
list1 = [1, 2, 3, 4]
print(2 in list1)
print(5 in list1)

# %% [markdown]
# ## **Identity Operators**

# %% [markdown]
# - Used to compare memory locations.

# %% [markdown]
# | Operator | Meaning         | Example      |
# | -------- | --------------- | ------------ |
# | `is`     | Same object     | `x is y`     |
# | `is not` | Not same object | `x is not y` |

# %%
# Examples
a = [1, 2, 3]
b = a
c = [1, 2, 3]

# %%
print(a is b)
print(a is c)

# %% [markdown]
# ✔ Solution
# - a is b → True (same memory location)
# - a is c → False (same values, different memory)
